# %%
import helpers.helpers as helpers
import matplotlib.pyplot as plt
import pandas as pd

# %%
file = 'C:\\Users\\Nand Chandravadia\\Desktop\\code\\Python\\COVID-19-Los-Angeles\\COVID-19.csv'

COVID19 = helpers.extractCOVID_data(file)

COVID19.plot.bar(x = 'Date', y = 'Total_Cases')
COVID19.plot.bar(x = 'Date', y = 'Total_New_Cases_LA')
COVID19.plot.bar(x = 'Date', y = 'Total_Cases_WestHollywood')

plt.show()
